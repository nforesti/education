# %%
# %matplotlib inline

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re

# %% [markdown]
# # City Datasets

# %%
cities_dataset_path = './datasets/cities/'
counties_dataset_path = './datasets/counties/'

# create separate dictionaries for each category of colleges that the cities are home to
top_cities = dict()
mid_cities = dict()
bot_cities = dict()
other_cities = dict() # misc areas for further analysis

# populate dicts based on filename indicators
for c in os.listdir(cities_dataset_path):
    # filenames truncated to city-state format for simplicity
    truncated_file_name = '-'.join((c.split('-')[:2]))
    if c.endswith("top-city.csv"):
        top_cities[truncated_file_name] = pd.read_csv(cities_dataset_path + c)
    elif c.endswith("mid-city.csv"):
        mid_cities[truncated_file_name] = pd.read_csv(cities_dataset_path + c)
    elif c.endswith("bot-city.csv"):
        bot_cities[truncated_file_name] = pd.read_csv(cities_dataset_path + c)
    elif '-' in c:
        other_cities[truncated_file_name] = pd.read_csv(cities_dataset_path + c)
print(top_cities.keys())
print(mid_cities.keys())
print(bot_cities.keys())
print(other_cities.keys())


# similar process for counties
top_counties = dict()
mid_counties = dict()
bot_counties = dict()
other_counties = dict()

for c in os.listdir(counties_dataset_path):
    # filenames truncated to county-state format for simplicity
    truncated_file_name = '-'.join((c.split('-')[:2]))
    if c.endswith("top-county.csv"):
        top_counties[truncated_file_name] = pd.read_csv(counties_dataset_path + c)
    elif c.endswith("mid-county.csv"):
        mid_counties[truncated_file_name] = pd.read_csv(counties_dataset_path + c)
    elif c.endswith("bot-county.csv"):
        bot_counties[truncated_file_name] = pd.read_csv(counties_dataset_path + c)
    elif '-' in c:
        other_counties[truncated_file_name] = pd.read_csv(counties_dataset_path + c)

# testing
print('============== TOP TEST ===============')
print(top_cities['stanford-ca'])
print('\n============== MID TEST ===============')
print(mid_cities['whitewater-wi'])
print('\n============== BOT TEST ===============')
print(bot_counties['westmoreland-pa'])
# Out:
# dict_keys(['cambridge-ma', 'newhaven-ct', 'stanford-ca'])
# dict_keys(['jacksonville-il', 'westerville-oh', 'whitewater-wi'])
# dict_keys(['greensburg-pa', 'redding-ca', 'sanbernardino-ca'])
# dict_keys(['berkeley-ca'])
# ============== TOP TEST ===============
#                                                  Fact  \
# 0        Population estimates, July 1, 2018,  (V2018)
# 1   Population estimates base, April 1, 2010,  (V2...
# 2   Population, percent change - April 1, 2010 (es...
# 3                   Population, Census, April 1, 2010
# 4                      Persons under 5 years, percent
# 5                     Persons under 18 years, percent
# 6                  Persons 65 years and over, percent
# 7                             Female persons, percent
# 8                                White alone, percent
# 9            Black or African American alone, percent
# 10   American Indian and Alaska Native alone, percent
# 11                               Asian alone, percent
# 12  Native Hawaiian and Other Pacific Islander alo...
# 13                         Two or More Races, percent
# 14                        Hispanic or Latino, percent
# 15       White alone, not Hispanic or Latino, percent
# 16                                Veterans, 2013-2017
# 17           Foreign born persons, percent, 2013-2017
# 18             Housing units,  July 1, 2017,  (V2017)
# 19        Owner-occupied housing unit rate, 2013-2017
# 20  Median value of owner-occupied housing units, ...
# 21  Median selected monthly owner costs -with a mo...
# 22  Median selected monthly owner costs -without a...
# 23                       Median gross rent, 2013-2017
# 24                             Building permits, 2017
# 25                              Households, 2013-2017
# 26                   Persons per household, 2013-2017
# 27  Living in same house 1 year ago, percent of pe...
# 28  Language other than English spoken at home, pe...
# 29     Households with a computer, percent, 2013-2017
# ..                                                ...
# 52                                    All firms, 2012
# 53                              Men-owned firms, 2012
# 54                            Women-owned firms, 2012
# 55                         Minority-owned firms, 2012
# 56                      Nonminority-owned firms, 2012
# 57                          Veteran-owned firms, 2012
# 58                       Nonveteran-owned firms, 2012
# 59                   Population per square mile, 2010
# 60                    Land area in square miles, 2010
# 61                                          FIPS Code
# 62                                                NaN
# 63  NOTE: FIPS Code values are enclosed in quotes ...
# 64                                                NaN
# 65                                        Value Notes
# 66                                               None
# 67                                                NaN
# 68                                         Fact Notes
# 69                                                (a)
# 70                                                (b)
# 71                                                (c)
# 72                                                NaN
# 73                                        Value Flags
# 74                                                  -
# 75                                                  D
# 76                                                  F
# 77                                                 FN
# 78                                                NaN
# 79                                                  S
# 80                                                  X
# 81                                                  Z
#
#                                             Fact Note  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 (a)
# 10                                                (a)
# 11                                                (a)
# 12                                                (a)
# 13                                                NaN
# 14                                                (b)
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69           Includes persons reporting only one race
# 70  Hispanics may be of any race, so also are incl...
# 71  Economic Census - Puerto Rico data are not com...
# 72                                                NaN
# 73                                                NaN
# 74  Either no or too few sample observations were ...
# 75  Suppressed to avoid disclosure of confidential...
# 76                                Fewer than 25 firms
# 77             Footnote on this item in place of data
# 78                                      Not available
# 79    Suppressed; does not meet publication standards
# 80                                     Not applicable
# 81  Value greater than zero but less than half uni...
#
#    Stanford CDP, California  Value Note for Stanford CDP, California
# 0                         X                                      NaN
# 1                         X                                      NaN
# 2                         X                                      NaN
# 3                    13,809                                      NaN
# 4                      2.8%                                      NaN
# 5                      7.6%                                      NaN
# 6                      3.9%                                      NaN
# 7                     43.9%                                      NaN
# 8                     56.6%                                      NaN
# 9                      4.3%                                      NaN
# 10                     0.4%                                      NaN
# 11                    27.0%                                      NaN
# 12                     0.3%                                      NaN
# 13                     9.7%                                      NaN
# 14                    13.6%                                      NaN
# 15                    47.4%                                      NaN
# 16                      107                                      NaN
# 17                    26.6%                                      NaN
# 18                        X                                      NaN
# 19                    27.9%                                      NaN
# 20               $1,591,300                                      NaN
# 21                   $3,922                                      NaN
# 22                   $1,363                                      NaN
# 23                   $1,592                                      NaN
# 24                        X                                      NaN
# 25                    3,286                                      NaN
# 26                     2.16                                      NaN
# 27                    54.2%                                      NaN
# 28                    41.1%                                      NaN
# 29                    99.9%                                      NaN
# ..                      ...                                      ...
# 52                      815                                      NaN
# 53                      424                                      NaN
# 54                      149                                      NaN
# 55                      173                                      NaN
# 56                      509                                      NaN
# 57                       79                                      NaN
# 58                      604                                      NaN
# 59                  5,056.4                                      NaN
# 60                     2.73                                      NaN
# 61                "0673906"                                      NaN
# 62                      NaN                                      NaN
# 63                      NaN                                      NaN
# 64                      NaN                                      NaN
# 65                      NaN                                      NaN
# 66                      NaN                                      NaN
# 67                      NaN                                      NaN
# 68                      NaN                                      NaN
# 69                      NaN                                      NaN
# 70                      NaN                                      NaN
# 71                      NaN                                      NaN
# 72                      NaN                                      NaN
# 73                      NaN                                      NaN
# 74                      NaN                                      NaN
# 75                      NaN                                      NaN
# 76                      NaN                                      NaN
# 77                      NaN                                      NaN
# 78                      NaN                                      NaN
# 79                      NaN                                      NaN
# 80                      NaN                                      NaN
# 81                      NaN                                      NaN
#
# [82 rows x 4 columns]
#
# ============== MID TEST ===============
#                                                  Fact  \
# 0        Population estimates, July 1, 2018,  (V2018)
# 1   Population estimates base, April 1, 2010,  (V2...
# 2   Population, percent change - April 1, 2010 (es...
# 3                   Population, Census, April 1, 2010
# 4                      Persons under 5 years, percent
# 5                     Persons under 18 years, percent
# 6                  Persons 65 years and over, percent
# 7                             Female persons, percent
# 8                                White alone, percent
# 9            Black or African American alone, percent
# 10   American Indian and Alaska Native alone, percent
# 11                               Asian alone, percent
# 12  Native Hawaiian and Other Pacific Islander alo...
# 13                         Two or More Races, percent
# 14                        Hispanic or Latino, percent
# 15       White alone, not Hispanic or Latino, percent
# 16                                Veterans, 2013-2017
# 17           Foreign born persons, percent, 2013-2017
# 18             Housing units,  July 1, 2017,  (V2017)
# 19        Owner-occupied housing unit rate, 2013-2017
# 20  Median value of owner-occupied housing units, ...
# 21  Median selected monthly owner costs -with a mo...
# 22  Median selected monthly owner costs -without a...
# 23                       Median gross rent, 2013-2017
# 24                             Building permits, 2017
# 25                              Households, 2013-2017
# 26                   Persons per household, 2013-2017
# 27  Living in same house 1 year ago, percent of pe...
# 28  Language other than English spoken at home, pe...
# 29     Households with a computer, percent, 2013-2017
# ..                                                ...
# 52                                    All firms, 2012
# 53                              Men-owned firms, 2012
# 54                            Women-owned firms, 2012
# 55                         Minority-owned firms, 2012
# 56                      Nonminority-owned firms, 2012
# 57                          Veteran-owned firms, 2012
# 58                       Nonveteran-owned firms, 2012
# 59                   Population per square mile, 2010
# 60                    Land area in square miles, 2010
# 61                                          FIPS Code
# 62                                                NaN
# 63  NOTE: FIPS Code values are enclosed in quotes ...
# 64                                                NaN
# 65                                        Value Notes
# 66                                               None
# 67                                                NaN
# 68                                         Fact Notes
# 69                                                (a)
# 70                                                (b)
# 71                                                (c)
# 72                                                NaN
# 73                                        Value Flags
# 74                                                  -
# 75                                                  D
# 76                                                  F
# 77                                                 FN
# 78                                                NaN
# 79                                                  S
# 80                                                  X
# 81                                                  Z
#
#                                             Fact Note  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 (a)
# 10                                                (a)
# 11                                                (a)
# 12                                                (a)
# 13                                                NaN
# 14                                                (b)
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69           Includes persons reporting only one race
# 70  Hispanics may be of any race, so also are incl...
# 71  Economic Census - Puerto Rico data are not com...
# 72                                                NaN
# 73                                                NaN
# 74  Either no or too few sample observations were ...
# 75  Suppressed to avoid disclosure of confidential...
# 76                                Fewer than 25 firms
# 77             Footnote on this item in place of data
# 78                                      Not available
# 79    Suppressed; does not meet publication standards
# 80                                     Not applicable
# 81  Value greater than zero but less than half uni...
#
#    Whitewater city, Wisconsin  Value Note for Whitewater city, Wisconsin
# 0                         NaN                                        NaN
# 1                         NaN                                        NaN
# 2                         NaN                                        NaN
# 3                      14,390                                        NaN
# 4                        3.7%                                        NaN
# 5                       10.3%                                        NaN
# 6                        8.1%                                        NaN
# 7                       48.7%                                        NaN
# 8                       87.9%                                        NaN
# 9                        3.8%                                        NaN
# 10                       0.1%                                        NaN
# 11                       2.1%                                        NaN
# 12                       0.6%                                        NaN
# 13                       2.9%                                        NaN
# 14                       9.6%                                        NaN
# 15                      81.8%                                        NaN
# 16                        371                                        NaN
# 17                       5.3%                                        NaN
# 18                          X                                        NaN
# 19                      33.5%                                        NaN
# 20                   $164,400                                        NaN
# 21                     $1,479                                        NaN
# 22                       $548                                        NaN
# 23                       $722                                        NaN
# 24                          X                                        NaN
# 25                      4,609                                        NaN
# 26                       2.36                                        NaN
# 27                      53.3%                                        NaN
# 28                       9.2%                                        NaN
# 29                      88.7%                                        NaN
# ..                        ...                                        ...
# 52                        626                                        NaN
# 53                        379                                        NaN
# 54                        183                                        NaN
# 55                         63                                        NaN
# 56                        531                                        NaN
# 57                        104                                        NaN
# 58                        470                                        NaN
# 59                    1,643.4                                        NaN
# 60                       8.76                                        NaN
# 61                  "5586925"                                        NaN
# 62                        NaN                                        NaN
# 63                        NaN                                        NaN
# 64                        NaN                                        NaN
# 65                        NaN                                        NaN
# 66                        NaN                                        NaN
# 67                        NaN                                        NaN
# 68                        NaN                                        NaN
# 69                        NaN                                        NaN
# 70                        NaN                                        NaN
# 71                        NaN                                        NaN
# 72                        NaN                                        NaN
# 73                        NaN                                        NaN
# 74                        NaN                                        NaN
# 75                        NaN                                        NaN
# 76                        NaN                                        NaN
# 77                        NaN                                        NaN
# 78                        NaN                                        NaN
# 79                        NaN                                        NaN
# 80                        NaN                                        NaN
# 81                        NaN                                        NaN
#
# [82 rows x 4 columns]
#
# ============== BOT TEST ===============
#                                                  Fact  \
# 0        Population estimates, July 1, 2018,  (V2018)
# 1   Population estimates base, April 1, 2010,  (V2...
# 2   Population, percent change - April 1, 2010 (es...
# 3                   Population, Census, April 1, 2010
# 4                      Persons under 5 years, percent
# 5                     Persons under 18 years, percent
# 6                  Persons 65 years and over, percent
# 7                             Female persons, percent
# 8                                White alone, percent
# 9            Black or African American alone, percent
# 10   American Indian and Alaska Native alone, percent
# 11                               Asian alone, percent
# 12  Native Hawaiian and Other Pacific Islander alo...
# 13                         Two or More Races, percent
# 14                        Hispanic or Latino, percent
# 15       White alone, not Hispanic or Latino, percent
# 16                                Veterans, 2013-2017
# 17           Foreign born persons, percent, 2013-2017
# 18             Housing units,  July 1, 2017,  (V2017)
# 19        Owner-occupied housing unit rate, 2013-2017
# 20  Median value of owner-occupied housing units, ...
# 21  Median selected monthly owner costs -with a mo...
# 22  Median selected monthly owner costs -without a...
# 23                       Median gross rent, 2013-2017
# 24                             Building permits, 2017
# 25                              Households, 2013-2017
# 26                   Persons per household, 2013-2017
# 27  Living in same house 1 year ago, percent of pe...
# 28  Language other than English spoken at home, pe...
# 29     Households with a computer, percent, 2013-2017
# ..                                                ...
# 52                                    All firms, 2012
# 53                              Men-owned firms, 2012
# 54                            Women-owned firms, 2012
# 55                         Minority-owned firms, 2012
# 56                      Nonminority-owned firms, 2012
# 57                          Veteran-owned firms, 2012
# 58                       Nonveteran-owned firms, 2012
# 59                   Population per square mile, 2010
# 60                    Land area in square miles, 2010
# 61                                          FIPS Code
# 62                                                NaN
# 63  NOTE: FIPS Code values are enclosed in quotes ...
# 64                                                NaN
# 65                                        Value Notes
# 66                                               None
# 67                                                NaN
# 68                                         Fact Notes
# 69                                                (a)
# 70                                                (b)
# 71                                                (c)
# 72                                                NaN
# 73                                        Value Flags
# 74                                                  -
# 75                                                  D
# 76                                                  F
# 77                                                 FN
# 78                                                NaN
# 79                                                  S
# 80                                                  X
# 81                                                  Z
#
#                                             Fact Note  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 (a)
# 10                                                (a)
# 11                                                (a)
# 12                                                (a)
# 13                                                NaN
# 14                                                (b)
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69           Includes persons reporting only one race
# 70  Hispanics may be of any race, so also are incl...
# 71  Economic Census - Puerto Rico data are not com...
# 72                                                NaN
# 73                                                NaN
# 74  Either no or too few sample observations were ...
# 75  Suppressed to avoid disclosure of confidential...
# 76                                Fewer than 25 firms
# 77             Footnote on this item in place of data
# 78                                      Not available
# 79    Suppressed; does not meet publication standards
# 80                                     Not applicable
# 81  Value greater than zero but less than half uni...
#
#    Westmoreland County, Pennsylvania  \
# 0                            350,611
# 1                            365,194
# 2                              -4.0%
# 3                            365,169
# 4                               4.6%
# 5                              18.4%
# 6                              22.1%
# 7                              51.1%
# 8                              94.9%
# 9                               2.5%
# 10                              0.1%
# 11                              1.0%
# 12                                 Z
# 13                              1.5%
# 14                              1.2%
# 15                             93.9%
# 16                            27,539
# 17                              1.5%
# 18                           170,475
# 19                             77.6%
# 20                          $144,900
# 21                            $1,202
# 22                              $459
# 23                              $674
# 24                               385
# 25                           151,892
# 26                              2.30
# 27                             90.6%
# 28                              2.7%
# 29                             82.5%
# ..                               ...
# 52                            27,796
# 53                            16,593
# 54                             8,449
# 55                               906
# 56                            25,985
# 57                             3,055
# 58                            23,377
# 59                             355.4
# 60                          1,027.55
# 61                           "42129"
# 62                               NaN
# 63                               NaN
# 64                               NaN
# 65                               NaN
# 66                               NaN
# 67                               NaN
# 68                               NaN
# 69                               NaN
# 70                               NaN
# 71                               NaN
# 72                               NaN
# 73                               NaN
# 74                               NaN
# 75                               NaN
# 76                               NaN
# 77                               NaN
# 78                               NaN
# 79                               NaN
# 80                               NaN
# 81                               NaN
#
#     Value Note for Westmoreland County, Pennsylvania
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# ..                                               ...
# 52                                               NaN
# 53                                               NaN
# 54                                               NaN
# 55                                               NaN
# 56                                               NaN
# 57                                               NaN
# 58                                               NaN
# 59                                               NaN
# 60                                               NaN
# 61                                               NaN
# 62                                               NaN
# 63                                               NaN
# 64                                               NaN
# 65                                               NaN
# 66                                               NaN
# 67                                               NaN
# 68                                               NaN
# 69                                               NaN
# 70                                               NaN
# 71                                               NaN
# 72                                               NaN
# 73                                               NaN
# 74                                               NaN
# 75                                               NaN
# 76                                               NaN
# 77                                               NaN
# 78                                               NaN
# 79                                               NaN
# 80                                               NaN
# 81                                               NaN
#
# [82 rows x 4 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The first part of the data we wanted to clean was simply the name of the column that holds all the statistic values. The name was originally just the name of the county/city. We believe that changing it to "fact_value" (given that the column with the name of the statistic is "fact", would be more clear.

# %%
all_csv = [top_cities, mid_cities, bot_cities, other_cities, top_counties, mid_counties, bot_counties, other_counties]
for d in all_csv:
    for k, v in d.items():
        v.rename(index = str, columns = {v.columns[2] : 'Fact Value'}, inplace = True)

assert top_cities['cambridge-ma'].columns[2] == 'Fact Value'

# %% [markdown]
# Currently, the column that should hold the fact value is of type object. We want this to be converted to ints so that we do not need to constantly type cast.
#
# We don't need all these rows. Only interested in demographic data.

# %%
invalid_values = ['X', 'NA', 'D', '-', 'FN', 'F', 'S', 'Z', 'NaN']
for d in all_csv:
    for k, v in d.items():
        for i, r in v.iterrows():
            if r['Fact Value'] in invalid_values:
                v.drop(i, inplace = True)
print(top_cities['stanford-ca'])
# Out:
#                                                  Fact  \
# 3                   Population, Census, April 1, 2010
# 4                      Persons under 5 years, percent
# 5                     Persons under 18 years, percent
# 6                  Persons 65 years and over, percent
# 7                             Female persons, percent
# 8                                White alone, percent
# 9            Black or African American alone, percent
# 10   American Indian and Alaska Native alone, percent
# 11                               Asian alone, percent
# 12  Native Hawaiian and Other Pacific Islander alo...
# 13                         Two or More Races, percent
# 14                        Hispanic or Latino, percent
# 15       White alone, not Hispanic or Latino, percent
# 16                                Veterans, 2013-2017
# 17           Foreign born persons, percent, 2013-2017
# 19        Owner-occupied housing unit rate, 2013-2017
# 20  Median value of owner-occupied housing units, ...
# 21  Median selected monthly owner costs -with a mo...
# 22  Median selected monthly owner costs -without a...
# 23                       Median gross rent, 2013-2017
# 25                              Households, 2013-2017
# 26                   Persons per household, 2013-2017
# 27  Living in same house 1 year ago, percent of pe...
# 28  Language other than English spoken at home, pe...
# 29     Households with a computer, percent, 2013-2017
# 30  Households with a broadband Internet subscript...
# 31  High school graduate or higher, percent of per...
# 32  Bachelor's degree or higher, percent of person...
# 33  With a disability, under age 65 years, percent...
# 34  Persons  without health insurance, under age 6...
# ..                                                ...
# 52                                    All firms, 2012
# 53                              Men-owned firms, 2012
# 54                            Women-owned firms, 2012
# 55                         Minority-owned firms, 2012
# 56                      Nonminority-owned firms, 2012
# 57                          Veteran-owned firms, 2012
# 58                       Nonveteran-owned firms, 2012
# 59                   Population per square mile, 2010
# 60                    Land area in square miles, 2010
# 61                                          FIPS Code
# 62                                                NaN
# 63  NOTE: FIPS Code values are enclosed in quotes ...
# 64                                                NaN
# 65                                        Value Notes
# 66                                               None
# 67                                                NaN
# 68                                         Fact Notes
# 69                                                (a)
# 70                                                (b)
# 71                                                (c)
# 72                                                NaN
# 73                                        Value Flags
# 74                                                  -
# 75                                                  D
# 76                                                  F
# 77                                                 FN
# 78                                                NaN
# 79                                                  S
# 80                                                  X
# 81                                                  Z
#
#                                             Fact Note  Fact Value  \
# 3                                                 NaN      13,809
# 4                                                 NaN        2.8%
# 5                                                 NaN        7.6%
# 6                                                 NaN        3.9%
# 7                                                 NaN       43.9%
# 8                                                 NaN       56.6%
# 9                                                 (a)        4.3%
# 10                                                (a)        0.4%
# 11                                                (a)       27.0%
# 12                                                (a)        0.3%
# 13                                                NaN        9.7%
# 14                                                (b)       13.6%
# 15                                                NaN       47.4%
# 16                                                NaN         107
# 17                                                NaN       26.6%
# 19                                                NaN       27.9%
# 20                                                NaN  $1,591,300
# 21                                                NaN      $3,922
# 22                                                NaN      $1,363
# 23                                                NaN      $1,592
# 25                                                NaN       3,286
# 26                                                NaN        2.16
# 27                                                NaN       54.2%
# 28                                                NaN       41.1%
# 29                                                NaN       99.9%
# 30                                                NaN       58.0%
# 31                                                NaN       98.9%
# 32                                                NaN       95.3%
# 33                                                NaN        4.0%
# 34                                                NaN        3.3%
# ..                                                ...         ...
# 52                                                NaN         815
# 53                                                NaN         424
# 54                                                NaN         149
# 55                                                NaN         173
# 56                                                NaN         509
# 57                                                NaN          79
# 58                                                NaN         604
# 59                                                NaN     5,056.4
# 60                                                NaN        2.73
# 61                                                NaN   "0673906"
# 62                                                NaN         NaN
# 63                                                NaN         NaN
# 64                                                NaN         NaN
# 65                                                NaN         NaN
# 66                                                NaN         NaN
# 67                                                NaN         NaN
# 68                                                NaN         NaN
# 69           Includes persons reporting only one race         NaN
# 70  Hispanics may be of any race, so also are incl...         NaN
# 71  Economic Census - Puerto Rico data are not com...         NaN
# 72                                                NaN         NaN
# 73                                                NaN         NaN
# 74  Either no or too few sample observations were ...         NaN
# 75  Suppressed to avoid disclosure of confidential...         NaN
# 76                                Fewer than 25 firms         NaN
# 77             Footnote on this item in place of data         NaN
# 78                                      Not available         NaN
# 79    Suppressed; does not meet publication standards         NaN
# 80                                     Not applicable         NaN
# 81  Value greater than zero but less than half uni...         NaN
#
#     Value Note for Stanford CDP, California
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
# 30                                      NaN
# 31                                      NaN
# 32                                      NaN
# 33                                      NaN
# 34                                      NaN
# ..                                      ...
# 52                                      NaN
# 53                                      NaN
# 54                                      NaN
# 55                                      NaN
# 56                                      NaN
# 57                                      NaN
# 58                                      NaN
# 59                                      NaN
# 60                                      NaN
# 61                                      NaN
# 62                                      NaN
# 63                                      NaN
# 64                                      NaN
# 65                                      NaN
# 66                                      NaN
# 67                                      NaN
# 68                                      NaN
# 69                                      NaN
# 70                                      NaN
# 71                                      NaN
# 72                                      NaN
# 73                                      NaN
# 74                                      NaN
# 75                                      NaN
# 76                                      NaN
# 77                                      NaN
# 78                                      NaN
# 79                                      NaN
# 80                                      NaN
# 81                                      NaN
#
# [67 rows x 4 columns]

# %%
print('Column types before cleaning:')
print(top_cities['stanford-ca'].dtypes)
for d in all_csv:
    for k, v in d.items():
        v.loc[:, 'Fact Value'] = v.loc[:, 'Fact Value'].str.strip('%"$')
        v.loc[:, 'Fact Value'] = v.loc[:, 'Fact Value'].str.replace(',', '')   
        v.loc[:, 'Fact Value'] = v.loc[:, 'Fact Value'].astype('float64')
print('\nColumn types after cleaning:')
print(top_cities['stanford-ca'].dtypes)
# Out:
# Column types before cleaning:
# Fact                                        object
# Fact Note                                   object
# Fact Value                                  object
# Value Note for Stanford CDP, California    float64
# dtype: object
#
# Column types after cleaning:
# Fact                                        object
# Fact Note                                   object
# Fact Value                                 float64
# Value Note for Stanford CDP, California    float64
# dtype: object

# %% [markdown]
# As seen in the above output, there are a couple of entirely or largely unneeded columns in the data where all the values are either NaN or irrelevant.
#
# We will be dropping or modifying the following columns to clean the data:
#
# Fact Note:
#
# This indicates
# (a) Includes persons reporting only one race
# (b) Hispanics may be of any race, so also are included in applicable race categories
# (c) Economic Census - Puerto Rico data are not comparable to U.S. Economic Census Data.
#
# As none of these factors influence the demographic data of the areas we are analyzing, we can remove this data.
#
# Value Note:
#
# This indicates
# (-) Either no or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest or upper interval of an open ended distribution.
# (D)	Suppressed to avoid disclosure of confidential information
# (F)	Fewer than 25 firms
# (FN) Footnote on this item in place of data
# (NA) Not available
# (S)	Suppressed; does not meet publication standards
# (X)	Not applicable
# (Z)	Value greater than zero but less than half unit of measure shown
#
# Value notes are indicated in the fact value column so we do not need the value note column at all.

# %%
# get rid of useless columns and rows (those that are not demographic related)
# get rid of all rows with NaNs
